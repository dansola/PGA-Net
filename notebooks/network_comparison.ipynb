# %%
import json
import matplotlib.pyplot as plt

# %%
with open('/home/dsola/repos/PGA-Net/results/distinctive_snowflake_167_small_axial_lbc_city-mean-iou-epoch.json', 'r') as fp:
    axial_iou = json.load(fp)
with open('/home/dsola/repos/PGA-Net/results/wild_sun_150_city_unet_ignore_index-mean-iou-epoch.json', 'r') as fp:
    unet_iou = json.load(fp)
with open('/home/dsola/repos/PGA-Net/results/distinctive_snowflake_167_small_axial_lbc_city-mean-iou-epoch-128-256-size.json', 'r') as fp:
    axial_iou_small = json.load(fp)
with open('/home/dsola/repos/PGA-Net/results/glorious_haze_169_unet_city_128_256_size-mean-iou-epoch.json', 'r') as fp:
    unet_iou_small = json.load(fp)
with open('/home/dsola/repos/PGA-Net/results/quiet_wildflower_208_full_axial_unet_lbc_city-mean-iou-epoch-128-256-size.json', 'r') as fp:
    axial_full_iou = json.load(fp)    

with open('/home/dsola/repos/PGA-Net/results/distinctive_snowflake_167_small_axial_lbc_city-mean-acc-epoch.json', 'r') as fp:
    axial_acc = json.load(fp)
with open('/home/dsola/repos/PGA-Net/results/wild_sun_150_city_unet_ignore_index-mean-acc-epoch.json', 'r') as fp:
    unet_acc = json.load(fp)
with open('/home/dsola/repos/PGA-Net/results/distinctive_snowflake_167_small_axial_lbc_city-mean-acc-epoch-128-256-size.json', 'r') as fp:
    axial_acc_small = json.load(fp)
with open('/home/dsola/repos/PGA-Net/results/glorious_haze_169_unet_city_128_256_size-mean-acc-epoch.json', 'r') as fp:
    unet_acc_small = json.load(fp)
with open('/home/dsola/repos/PGA-Net/results/quiet_wildflower_208_full_axial_unet_lbc_city-mean-acc-epoch-128-256-size.json', 'r') as fp:
    axial_full_acc = json.load(fp)

# %%
fig, ax = plt.subplots()

ax.plot(list(axial_iou.keys()), list(axial_iou.values()), label='axial-lbc')
ax.plot(list(unet_iou.keys()), list(unet_iou.values()), label='unet')
ax.plot(list(axial_iou_small.keys()), list(axial_iou_small.values()), label='axial-lbc-small')
ax.plot(list(unet_iou_small.keys()), list(unet_iou_small.values()), label='unet-small')
ax.plot(list(axial_full_iou.keys()), list(axial_full_iou.values()), label='unet-full')
plt.legend()

# %%
fig, ax = plt.subplots()

ax.plot(list(axial_acc.keys()), list(axial_acc.values()), label='axial-lbc')
ax.plot(list(unet_acc.keys()), list(unet_acc.values()), label='unet')
ax.plot(list(axial_acc_small.keys()), list(axial_acc_small.values()), label='axial-lbc-small')
ax.plot(list(unet_acc_small.keys()), list(unet_acc_small.values()), label='unet-small')
ax.plot(list(axial_full_acc.keys()), list(axial_full_acc.values()), label='unet-full')
plt.legend()
